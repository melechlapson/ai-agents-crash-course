# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI

dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# We are up and running!

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
nutrition_agent = Agent(name='Nurition Assistant', instructions="You are a helpful assistant giving nutrition advice")

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are bananas?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nurition Assistant", ...)
# - Final output (str):
#     Overall, bananas are a healthy, convenient fruit with several benefits, but like all foods they’re best in context.
#
#     What they provide (per medium banana, about 118 g):
#     - Calories: ~105
#     - Carbs: ~27 g (natural sugars ~14 g)
#     - Fiber: ~3 g
#     - Potassium: ~422 mg
#     - Vitamin C and vitamin B6
#     - Some resistant starch when unripe, which acts like a prebiotic
#
#     Health benefits:
#     - Support heart and muscle function (potassium, magnesium, vitamin B6)
#     - Good source of quick energy from natural sugars
#     - Filled with fiber and antioxidants
#
#     Things to consider:
#     - Higher sugar content for some diets (diabetes, calorie tracking) — pair with protein/fat to blunt sugar spike
#     - Potassium considerations: generally healthy, but people with certain kidney conditions may need to monitor intake
#
#     Bottom line:
#     - Bananas are a nutritious, convenient fruit that fit most balanced diets. If you have kidney issues or need to manage sugar intake, adjust portion size or pair with other foods. Any specific dietary goal or restriction you want me to tailor to?
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Bananas are a healthy, convenient fruit. Here’s a quick snapshot:
#
# Pros
# - Rich in potassium (supports heart and muscle function)
# - Good fiber (supports digestion)
# - Vitamin C and B6 (antioxidant support and metabolism)
# - Moderate calories and natural sugars; easy to portion
#
# What a typical banana provides (about 118 g)
# - Calories: ~105
# - Carbs: ~27 g (includes ~14 g sugars and ~3 g fiber)
# - Protein: ~1 g
# - Fat: ~0.3 g
# - Potassium: ~422 mg
# - Vitamin C: ~10 mg
# - Vitamin B6: ~0.5 mg
#
# Considerations
# - If you have kidney disease or need to limit potassium, watch portions and follow medical guidance.
# - The ripeness changes sugar content: greener bananas are starchier (lower sugar, higher resistant starch); ripe bananas are sweeter (higher sugar).
# - People with diabetes should monitor portion and overall carb intake as part of meals.
#
# Healthy ideas
# - Pair with protein (peanut butter, yogurt, cheese) for staying power
# - Add to smoothies, oats, or kales salads
# - Freeze and blend into smoothies or use in desserts
#
# If you have a specific goal or dietary need, tell me and I’ll tailor the advice.

# %% [markdown]
# _Good Job!_
