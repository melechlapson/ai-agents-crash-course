# %% [markdown]
# # Short-Term Memory

# %%
import dotenv
from agents import Agent, Runner, SQLiteSession, trace

dotenv.load_dotenv()
# Out:
# True

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant comparing how healthy different foods are.
    If you answer, give a list of how healthy the foods are with a score from 1 to 10. Order by: healtiest food comes first.

    Example:
    Q: Compare X and Y
    A: X is healtier as Y.
    1) X: 8/10 - Very healthy but high in fructose
    2) Y: 3/10 - High in sugar and fat
    """,
)

# %% [markdown]
# ## No Memory

# %%
result = await Runner.run(nutrition_agent, "Which is healthier, bananas or lollipop?")
print(result.final_output)
# Out:
# Bananas vs Lollipop:
#
# 1) Bananas: 8/10 - Nutrient-dense (fiber, potassium, vitamins); natural sugars but balanced.
# 2) Lollipop: 2/10 - Mostly sugar, little to no nutrients; can contribute to cavities.

# %%
result = await Runner.run(nutrition_agent, "Add apples to the comparison")
print(result.final_output)
# Out:
# Which foods should I compare? Please list the foods (including apples) you want rated, e.g., apples, bananas, almonds, cookies. If you want apples added to a specific existing list, share that list.

# %% [markdown]
# ## Short Term Memory

# %%
session = SQLiteSession("conversation_history")

# %%
result = await Runner.run(
    nutrition_agent, "Which is healthier, bananas or lollipop?", session=session
)
print(result.final_output)
# Out:
# 1) Banana: 8/10 - Natural sugars plus fiber, potassium, and vitamins.
# 2) Lollipop: 2/10 - Mostly sugar with no nutrients.

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(
        nutrition_agent, "Add apples to the comparison",
        session=session
    )

print(result.final_output)
# Out:
# 1) Apple: 9/10 - Fiber and vitamins; natural sweetness with minimal processing.
# 2) Banana: 8/10 - Potassium, fiber, and vitamins; natural sugars but balanced.
# 3) Lollipop: 2/10 - Pure sugar with no nutrients.
